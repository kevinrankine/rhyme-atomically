-- %%
require 'nn'
require 'rnn'

-- %%
nn.LSTM(100, 100)
-- Out:
-- nn.LSTM(100 -> 100)
-- {
--   outputGate :
--  nn.Sequential {
--       [input -> (1) -> (2) -> (3) -> output]
--       (1): nn.ParallelTable {
--         input
--           |`-> (1): nn.Linear(100 -> 100)
--           |`-> (2): nn.LinearNoBias(100 -> 100) without bias
--           |`-> (3): nn.CMul
--            ... -> output
--       }
--       (2): nn.CAddTable
--       (3): nn.Sigmoid
--     }
--     {
--       gradInput : table: 0x0c6dbb10
--       modules :
--         {
--           1 :
--             nn.ParallelTable {
--               input
--                 |`-> (1): nn.Linear(100 -> 100)
--                 |`-> (2): nn.LinearNoBias(100 -> 100) without bias
--                 |`-> (3): nn.CMul
--                  ... -> output
--             }
--             {
--               gradInput : table: 0x0c6dbb10
--               modules :
--                 {
--                   1 : nn.Linear(100 -> 100)
--                   2 : nn.LinearNoBias(100 -> 100) without bias
-- ...
